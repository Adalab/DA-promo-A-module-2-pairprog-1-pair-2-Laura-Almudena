# %%
#cargar el dataset
import pandas as pd

archivo = pd.read_csv("./attacks.csv")
archivo.head()
# Out:
#    Unnamed: 0 Case Number    Year        Type    Country             Area  \
# 0           0  2018.06.25  2018.0     Boating        USA       California
# 1           1  2018.06.18  2018.0  Unprovoked        USA          Georgia
# 2           2  2018.06.09  2018.0     Invalid        USA           Hawaii
# 3           3  2018.06.08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4           4  2018.06.04  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#           Species           Investigator or Source                       pdf  \
# 0      White shark                R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1              NaN  K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2              NaN  K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3        2 m shark                  B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4  Tiger shark, 3m                       A .Kipper      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   Case Number.2 original order Unnamed: 22  Unnamed: 23
# 0    2018.06.25         6303.0         NaN          NaN
# 1    2018.06.18         6302.0         NaN          NaN
# 2    2018.06.09         6301.0         NaN          NaN
# 3    2018.06.08         6300.0         NaN          NaN
# 4    2018.06.04         6299.0         NaN          NaN
#
# [5 rows x 22 columns]

# %%
# cuantas filas y columnas tiene el df
archivo_df = pd.DataFrame(archivo)

archivo_df.shape
# Out:
# (6114, 22)

# %%
# primeras 5 filas y las últimas 5
archivo_df.head(5)
# Out:
#    Unnamed: 0 Case Number    Year        Type    Country             Area  \
# 0           0  2018.06.25  2018.0     Boating        USA       California
# 1           1  2018.06.18  2018.0  Unprovoked        USA          Georgia
# 2           2  2018.06.09  2018.0     Invalid        USA           Hawaii
# 3           3  2018.06.08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4           4  2018.06.04  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#           Species           Investigator or Source                       pdf  \
# 0      White shark                R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1              NaN  K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2              NaN  K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3        2 m shark                  B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4  Tiger shark, 3m                       A .Kipper      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   Case Number.2 original order Unnamed: 22  Unnamed: 23
# 0    2018.06.25         6303.0         NaN          NaN
# 1    2018.06.18         6302.0         NaN          NaN
# 2    2018.06.09         6301.0         NaN          NaN
# 3    2018.06.08         6300.0         NaN          NaN
# 4    2018.06.04         6299.0         NaN          NaN
#
# [5 rows x 22 columns]

# %%
# 5 últimas filas
archivo_df.tail(5)
# Out:
#       Unnamed: 0   Case Number    Year          Type    Country  \
# 6109        6127  1804.02.26.R  1804.0          Boat  AUSTRALIA
# 6110        6128    1803.05.17  1803.0  Sea Disaster        USA
# 6111        6129    1803.03.00  1803.0    Unprovoked  AUSTRALIA
# 6112        6130  1802.04.13.R  1802.0    Unprovoked      INDIA
# 6113        6131  1801.12.18.R  1801.0      Provoked        NaN
#
#                    Area                          Location  \
# 6109    New South Wales    Georges Head, off Port Jackson
# 6110     South Carolina                    Off Charleston
# 6111  Western Australia  Hamelin Harbour, at Faure Island
# 6112                NaN                               NaN
# 6113                NaN                               NaN
#
#                              Activity                             Name Sex   \
# 6109                              NaN                             boat  NaN
# 6110                              NaN                    Captain Jones    M
# 6111                              NaN  M. Lefevre & a sailor (rescuer)    M
# 6112                              NaN                              NaN  NaN
# 6113  Standing on landed shark's tail                 Stephen Pettigew    N
#
#       ...   Species                              Investigator or Source  \
# 6109  ...        NaN                         Sydney Gazette, 2/26/1804
# 6110  ...        NaN                            Evening Post, 6/13/1803
# 6111  ...        NaN  F.  Peron ref in G.P. Whitley (Fishes of Austr...
# 6112  ...        NaN                  Evening Post (New York) 4/13/1802
# 6113  ...  12' shark                       The Evening Post, 12/18/1801
#
#                                   pdf  \
# 6109  1804.02.26-boat-GeorgesHead.pdf
# 6110             1803.05.17-Jones.pdf
# 6111           1803.03.00-Lefevre.pdf
# 6112           1802.04.13.R-India.pdf
# 6113       1801.12.18.R-Pettigrew.pdf
#
#                                            href formula  \
# 6109  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6110  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6111  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6112  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6113  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 6109  http://sharkattackfile.net/spreadsheets/pdf_di...  1804.02.26.R
# 6110  http://sharkattackfile.net/spreadsheets/pdf_di...    1803.05.17
# 6111  http://sharkattackfile.net/spreadsheets/pdf_di...    1803.03.00
# 6112  http://sharkattackfile.net/spreadsheets/pdf_di...  1802.04.13.R
# 6113  http://sharkattackfile.net/spreadsheets/pdf_di...  1801.12.18.R
#
#      Case Number.2 original order Unnamed: 22  Unnamed: 23
# 6109  1804.02.26.R          176.0         NaN          NaN
# 6110    1803.05.17          175.0         NaN          NaN
# 6111    1803.03.00          174.0         NaN          NaN
# 6112  1802.04.13.R          173.0         NaN          NaN
# 6113  1801.12.18.R          172.0         NaN          NaN
#
# [5 rows x 22 columns]

# %%
# 2 filas al azar
archivo_df.sample(2)
# Out:
#      Unnamed: 0   Case Number    Year        Type           Country  \
# 486         487    2014.10.14  2014.0  Unprovoked               USA
# 840         844  2011.11.20.R  2011.0  Unprovoked  PAPUA NEW GUINEA
#
#                  Area                             Location  \
# 486    South Carolina  Hilton Head Island, Beaufort County
# 840  East New Britain                        Pigeon Island
#
#                    Activity        Name Sex   ...              Species   \
# 486  Standing in inner tube  Kyra Bandy    F  ...  Bull shark, 3' to 4'
# 840            Scuba diving        male    M  ...                   NaN
#
#                   Investigator or Source                            pdf  \
# 486           TheIndyChannel, 10/16,2014           2014.10.14-Bandy.pdf
# 840  you Tube, Shark Attack at 57 metres  2011.11.20.R-PigeonIsland.pdf
#
#                                           href formula  \
# 486  http://sharkattackfile.net/spreadsheets/pdf_di...
# 840  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                   href Case Number.1  \
# 486  http://sharkattackfile.net/spreadsheets/pdf_di...    2014.10.14
# 840  http://sharkattackfile.net/spreadsheets/pdf_di...  2011.11.20.R
#
#     Case Number.2 original order Unnamed: 22  Unnamed: 23
# 486    2014.10.14         5816.0         NaN          NaN
# 840  2011.11.20.R         5459.0         NaN          NaN
#
# [2 rows x 22 columns]

# %%
# nombres columnas
archivo_df.columns
# Out:
# Index(['Unnamed: 0', 'Case Number', 'Year', 'Type', 'Country', 'Area',
#        'Location', 'Activity', 'Name', 'Sex ', 'Age', 'Time', 'Species ',
#        'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
# principales estadísticos
archivo_df.describe()
# Out:
#         Unnamed: 0         Year  original order
# count  6114.000000  6114.000000     6114.000000
# mean   3065.554629  1968.831207     3237.445044
# std    1769.652139    43.745920     1769.652633
# min       0.000000  1801.000000      172.000000
# 25%    1534.250000  1946.000000     1706.250000
# 50%    3066.500000  1980.000000     3236.500000
# 75%    4596.750000  2005.000000     4768.750000
# max    6131.000000  2018.000000     6303.000000

# %%
# Mostrad por separado las variables categóricas y las variables numéricas.

categorica = archivo_df.describe(include = "object")                             # include --> funciona como un filtro.
categorica.head()
# Out:
#        Case Number        Type Country     Area  \
# count         6113        6110    6074     5706
# unique        6113           8     201      791
# top     2018.06.25  Unprovoked     USA  Florida
# freq             1        4438    2200     1025
#
#                                 Location Activity  Name  Sex    Age  \
# count                               5626     5603  5914  5564  3448
# unique                              4020     1484  5118     6   156
# top     New Smyrna Beach, Volusia County  Surfing  male     M    17
# freq                                 162      966   511  4939   154
#
#              Time     Species  Investigator or Source                     pdf  \
# count        2934         3409                   6098                    6114
# unique        366         1529                   4837                    6105
# top     Afternoon  White shark         C. Moore, GSAF  1898.00.00.R-Syria.pdf
# freq          183          161                     95                       2
#
#                                              href formula  \
# count                                                6113
# unique                                               6104
# top     http://sharkattackfile.net/spreadsheets/pdf_di...
# freq                                                    2
#
#                                                      href Case Number.1  \
# count                                                6114          6114
# unique                                               6099          6113
# top     http://sharkattackfile.net/spreadsheets/pdf_di...    1952.08.04
# freq                                                    4             2
#
#        Case Number.2   Unnamed: 22 Unnamed: 23
# count           6114             1           2
# unique          6114             1           2
# top       2018.06.25  stopped here      Teramo
# freq               1             1           1

# %%
numerica = archivo_df.describe(include = ("int64", "float64")) 
numerica.head()
# Out:
#         Unnamed: 0         Year  original order
# count  6114.000000  6114.000000     6114.000000
# mean   3065.554629  1968.831207     3237.445044
# std    1769.652139    43.745920     1769.652633
# min       0.000000  1801.000000      172.000000
# 25%    1534.250000  1946.000000     1706.250000

# %%
# porcentaje de valores nulos

casos_nulos = archivo_df.isnull().sum()
print(casos_nulos)

casos_totales = archivo_df.shape[0]         


resultado = (casos_nulos * 100) / casos_totales
print(resultado)


# % -->
#  casos total ----- 100 %
#  casos que tengo --- x % --->  X = (casos nulos * 100%) / casos totales
# Out:
# Unnamed: 0                   0
# Case Number                  1
# Year                         0
# Type                         4
# Country                     40
# Area                       408
# Location                   488
# Activity                   511
# Name                       200
# Sex                        550
# Age                       2666
# Time                      3180
# Species                   2705
# Investigator or Source      16
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               6113
# Unnamed: 23               6112
# dtype: int64
# Unnamed: 0                 0.000000
# Case Number                0.016356
# Year                       0.000000
# Type                       0.065424
# Country                    0.654236
# Area                       6.673209
# Location                   7.981681
# Activity                   8.357867
# Name                       3.271181
# Sex                        8.995747
# Age                       43.604841
# Time                      52.011776
# Species                   44.242722
# Investigator or Source     0.261694
# pdf                        0.000000
# href formula               0.016356
# href                       0.000000
# Case Number.1              0.000000
# Case Number.2              0.000000
# original order             0.000000
# Unnamed: 22               99.983644
# Unnamed: 23               99.967288
# dtype: float64

# %%
# Sacad los valores únicos y su frecuencia de las variables numéricas. 
# Almacenad los resultados en un diccionario.             

df_numericas = archivo_df[["Year", "original order", "Unnamed: 0"]]
dic = {}

for i in df_numericas:
    df_numericas[i].value_counts()
    dic[i] = df_numericas[i].value_counts()

# %%
dic.keys()
# Out:
# dict_keys(['Year', 'original order', 'Unnamed: 0'])

# %%
dic.values()
# Out:
# dict_values([2015.0    143
# 2017.0    136
# 2016.0    130
# 2011.0    128
# 2014.0    126
#          ...
# 1819.0      1
# 1822.0      1
# 1823.0      1
# 1834.0      1
# 1801.0      1
# Name: Year, Length: 207, dtype: int64, 569.0     2
# 6303.0    1
# 2208.0    1
# 2210.0    1
# 2211.0    1
#          ..
# 4260.0    1
# 4261.0    1
# 4262.0    1
# 4263.0    1
# 172.0     1
# Name: original order, Length: 6113, dtype: int64, 0       1
# 4084    1
# 4093    1
# 4092    1
# 4091    1
#        ..
# 2043    1
# 2042    1
# 2041    1
# 2040    1
# 6131    1
# Name: Unnamed: 0, Length: 6114, dtype: int64])

# %%
#cambiando los nombres de cols a minúsculas
#rename (utiliza dic. Keys: nombre antiguo, value nombre neuvo)

nuevas_columnas = {}

for col in archivo_df.columns:
    nuevas_columnas[col] = col.lower()
print(nuevas_columnas)
# Out:
# {'unnamed:_0': 'unnamed:_0', 'year': 'year', 'type': 'type', 'country': 'country', 'area': 'area', 'location': 'location', 'activity': 'activity', 'name': 'name', 'sex_': 'sex_', 'age': 'age', 'time': 'time', 'species_': 'species_', 'href': 'href'}

# %%
# ejemplo de Ana de list comprehension
# lista = ["Laura", "Almudena"]

# lista_nueva = []


# for nombre in lista:
#     lista_nueva.append(len(nombre))
# lista_nueva

# lista_nueva2 = [len(nombre) for nombre in lista]
# lista_nueva2
# Out:
# [5, 8]

# %%
# conviertiendo nombres cols a minúsculas con for cromprehension

nuevas_columnas2 = { col: col.lower() for col in archivo_df.columns}
nuevas_columnas2
# Out:
# {'unnamed:_0': 'unnamed:_0',
#  'year': 'year',
#  'type': 'type',
#  'country': 'country',
#  'area': 'area',
#  'location': 'location',
#  'activity': 'activity',
#  'name': 'name',
#  'sex_': 'sex_',
#  'age': 'age',
#  'time': 'time',
#  'species_': 'species_',
#  'href': 'href'}

# %%
# cambiando el nombre de las columnas
archivo_df.rename(columns = nuevas_columnas, inplace = True)
archivo_df.head()
# Out:
#    unnamed: 0 case number    year        type    country             area  \
# 0           0  2018.06.25  2018.0     Boating        USA       California
# 1           1  2018.06.18  2018.0  Unprovoked        USA          Georgia
# 2           2  2018.06.09  2018.0     Invalid        USA           Hawaii
# 3           3  2018.06.08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4           4  2018.06.04  2018.0    Provoked     MEXICO           Colima
#
#                          location     activity             name sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#           species           investigator or source                       pdf  \
# 0      White shark                R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1              NaN  K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2              NaN  K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3        2 m shark                  B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4  Tiger shark, 3m                       A .Kipper      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href case number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   case number.2 original order unnamed: 22  unnamed: 23
# 0    2018.06.25         6303.0         NaN          NaN
# 1    2018.06.18         6302.0         NaN          NaN
# 2    2018.06.09         6301.0         NaN          NaN
# 3    2018.06.08         6300.0         NaN          NaN
# 4    2018.06.04         6299.0         NaN          NaN
#
# [5 rows x 22 columns]

# %%
# reemplazad espacios por _

nuevas_columnas3 = {}

for col in archivo_df.columns:
    nuevas_columnas3[col] = col.replace(" ", "_")

archivo_df.rename(columns = nuevas_columnas3, inplace = True)
archivo_df.head()
# Out:
#              unnamed:_0    year        type    country             area  \
# case_number
# 2018.06.25            0  2018.0     Boating        USA       California
# 2018.06.18            1  2018.0  Unprovoked        USA          Georgia
# 2018.06.09            2  2018.0     Invalid        USA           Hawaii
# 2018.06.08            3  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 2018.06.04            4  2018.0    Provoked     MEXICO           Colima
#
#                                    location     activity             name  \
# case_number
# 2018.06.25      Oceanside, San Diego County     Paddling      Julie Wolfe
# 2018.06.18   St. Simon Island, Glynn County     Standing  Adyson McNeely
# 2018.06.09                     Habush, Oahu      Surfing      John Denges
# 2018.06.08               Arrawarra Headland      Surfing             male
# 2018.06.04                         La Ticla  Free diving   Gustavo Ramos
#
#             sex_  age           time         species_  \
# case_number
# 2018.06.25     F   57          18h00      White shark
# 2018.06.18     F   11  14h00  -15h00              NaN
# 2018.06.09     M   48          07h45              NaN
# 2018.06.08     M  NaN            NaN        2 m shark
# 2018.06.04     M  NaN            NaN  Tiger shark, 3m
#
#                                                           href
# case_number
# 2018.06.25   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2018.06.18   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2018.06.09   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2018.06.08   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2018.06.04   http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
## reemplazad espacios por _ con dict comprehension
chorizo = {col: col.replace(" ", "_") for col in archivo_df.columns}

# %%
# Eliminad las columnas de Unnamed: 22 y Unnamed: 23, Case Number.1, Case Number.2, original order, 
# Investigator or Source, pdf, href formula.

archivo_df.drop(["unnamed:_22", "unnamed:_23", "case_number.1", "case_number.2", "original_order", 
"investigator_or_source", "pdf", "href_formula"], axis = 1, inplace= True)

# %%
archivo_df
# Out:
#               unnamed:_0    year          type    country               area  \
# case_number
# 2018.06.25             0  2018.0       Boating        USA         California
# 2018.06.18             1  2018.0    Unprovoked        USA            Georgia
# 2018.06.09             2  2018.0       Invalid        USA             Hawaii
# 2018.06.08             3  2018.0    Unprovoked  AUSTRALIA    New South Wales
# 2018.06.04             4  2018.0      Provoked     MEXICO             Colima
# ...                  ...     ...           ...        ...                ...
# 1804.02.26.R        6127  1804.0          Boat  AUSTRALIA    New South Wales
# 1803.05.17          6128  1803.0  Sea Disaster        USA     South Carolina
# 1803.03.00          6129  1803.0    Unprovoked  AUSTRALIA  Western Australia
# 1802.04.13.R        6130  1802.0    Unprovoked      INDIA                NaN
# 1801.12.18.R        6131  1801.0      Provoked        NaN                NaN
#
#                                       location  \
# case_number
# 2018.06.25         Oceanside, San Diego County
# 2018.06.18      St. Simon Island, Glynn County
# 2018.06.09                        Habush, Oahu
# 2018.06.08                  Arrawarra Headland
# 2018.06.04                            La Ticla
# ...                                        ...
# 1804.02.26.R    Georges Head, off Port Jackson
# 1803.05.17                      Off Charleston
# 1803.03.00    Hamelin Harbour, at Faure Island
# 1802.04.13.R                               NaN
# 1801.12.18.R                               NaN
#
#                                      activity  \
# case_number
# 2018.06.25                           Paddling
# 2018.06.18                           Standing
# 2018.06.09                            Surfing
# 2018.06.08                            Surfing
# 2018.06.04                        Free diving
# ...                                       ...
# 1804.02.26.R                              NaN
# 1803.05.17                                NaN
# 1803.03.00                                NaN
# 1802.04.13.R                              NaN
# 1801.12.18.R  Standing on landed shark's tail
#
#                                          name sex_  age           time  \
# case_number
# 2018.06.25                        Julie Wolfe    F   57          18h00
# 2018.06.18                    Adyson McNeely     F   11  14h00  -15h00
# 2018.06.09                        John Denges    M   48          07h45
# 2018.06.08                               male    M  NaN            NaN
# 2018.06.04                     Gustavo Ramos     M  NaN            NaN
# ...                                       ...  ...  ...            ...
# 1804.02.26.R                             boat  NaN  NaN            NaN
# 1803.05.17                      Captain Jones    M  NaN            NaN
# 1803.03.00    M. Lefevre & a sailor (rescuer)    M  NaN            NaN
# 1802.04.13.R                              NaN  NaN  NaN            NaN
# 1801.12.18.R                 Stephen Pettigew    N  NaN            NaN
#
#                      species_  \
# case_number
# 2018.06.25        White shark
# 2018.06.18                NaN
# 2018.06.09                NaN
# 2018.06.08          2 m shark
# 2018.06.04    Tiger shark, 3m
# ...                       ...
# 1804.02.26.R              NaN
# 1803.05.17                NaN
# 1803.03.00                NaN
# 1802.04.13.R              NaN
# 1801.12.18.R        12' shark
#
#                                                            href
# case_number
# 2018.06.25    http://sharkattackfile.net/spreadsheets/pdf_di...
# 2018.06.18    http://sharkattackfile.net/spreadsheets/pdf_di...
# 2018.06.09    http://sharkattackfile.net/spreadsheets/pdf_di...
# 2018.06.08    http://sharkattackfile.net/spreadsheets/pdf_di...
# 2018.06.04    http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                         ...
# 1804.02.26.R  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1803.05.17    http://sharkattackfile.net/spreadsheets/pdf_di...
# 1803.03.00    http://sharkattackfile.net/spreadsheets/pdf_di...
# 1802.04.13.R  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1801.12.18.R  http://sharkattackfile.net/spreadsheets/pdf_di...
#
# [6114 rows x 13 columns]

# %%
# Establece la columna Case Number como índice del dataframe.
archivo_df.set_index("case_number", inplace = True)
archivo_df.head()
# Out:
#              unnamed:_0    year        type    country             area  \
# case_number
# 2018.06.25            0  2018.0     Boating        USA       California
# 2018.06.18            1  2018.0  Unprovoked        USA          Georgia
# 2018.06.09            2  2018.0     Invalid        USA           Hawaii
# 2018.06.08            3  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 2018.06.04            4  2018.0    Provoked     MEXICO           Colima
#
#                                    location     activity             name  \
# case_number
# 2018.06.25      Oceanside, San Diego County     Paddling      Julie Wolfe
# 2018.06.18   St. Simon Island, Glynn County     Standing  Adyson McNeely
# 2018.06.09                     Habush, Oahu      Surfing      John Denges
# 2018.06.08               Arrawarra Headland      Surfing             male
# 2018.06.04                         La Ticla  Free diving   Gustavo Ramos
#
#             sex_  age           time         species_  \
# case_number
# 2018.06.25     F   57          18h00      White shark
# 2018.06.18     F   11  14h00  -15h00              NaN
# 2018.06.09     M   48          07h45              NaN
# 2018.06.08     M  NaN            NaN        2 m shark
# 2018.06.04     M  NaN            NaN  Tiger shark, 3m
#
#                                                           href
# case_number
# 2018.06.25   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2018.06.18   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2018.06.09   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2018.06.08   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2018.06.04   http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
# Guarda el csv que no tiene esas columnas para seguir usándolo mañana.
archivo_df.to_csv("odisea.csv")
