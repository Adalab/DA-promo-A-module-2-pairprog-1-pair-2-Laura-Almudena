# %%
import pandas as pd
import numpy as np

# %%
# Cargad el csv que guardasteis ayer.
df = pd. read_csv("odisea.csv")

# %%
df.head()
# Out:
#   case_number    year        type    country             area  \
# 0  2018.06.25  2018.0     Boating        USA       California
# 1  2018.06.18  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  2018.0    Provoked     MEXICO           Colima
#
#                          location     activity             name sex_  age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#             time         species_  \
# 0          18h00      White shark
# 1  14h00  -15h00              NaN
# 2          07h45              NaN
# 3            NaN        2 m shark
# 4            NaN  Tiger shark, 3m
#
#                                                 href
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
#nº de filas de el df original (sin borar nan)
df_con_nans = df.shape
df_con_nans
# Out:
# (6114, 13)

# %%
#eliminando nulos del df
df.dropna(inplace = True)

# %%
df_sin_nans = df.shape
df_sin_nans
# Out:
# (1502, 13)

# %%
#se han borrado
nans_borrados = df_con_nans[0]-df_sin_nans[0]
nans_borrados
# Out:
# 4612

# %%
df.head()
# Out:
#      case_number    year        type    country        area  \
# 0     2018.06.25  2018.0     Boating        USA  California
# 6   2018.06.03.a  2018.0  Unprovoked     BRAZIL  Pernambuco
# 8   2018.05.26.b  2018.0  Unprovoked        USA     Florida
# 10    2018.05.24  2018.0    Provoked  AUSTRALIA  Queensland
# 13  2018.05.13.a  2018.0     Invalid    ENGLAND    Cornwall
#
#                         location        activity                    name sex_  \
# 0    Oceanside, San Diego County        Paddling             Julie Wolfe    F
# 6          Piedade Beach, Recife        Swimming  Jose Ernesto da Silva     M
# 8   Cocoa Beach, Brevard  County         Walking               Cody High    M
# 10               Cairns Aquarium  Feeding sharks                    male    M
# 13                Off Land's End         Fishing            Max Berryman    M
#
#    age            time          species_  \
# 0   57           18h00       White shark
# 6   18  Late afternoon       Tiger shark
# 8   15           17h00    Bull shark, 6'
# 10  32         Morning   Grey reef shark
# 13  21           08h15  Invalid incident
#
#                                                  href
# 0   http://sharkattackfile.net/spreadsheets/pdf_di...
# 6   http://sharkattackfile.net/spreadsheets/pdf_di...
# 8   http://sharkattackfile.net/spreadsheets/pdf_di...
# 10  http://sharkattackfile.net/spreadsheets/pdf_di...
# 13  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
# ¿Cuál es el número de ataques que se han producido en Estados Unidos?
df_usa = (df[df["country"] == "USA"])
len(df_usa)
# Out:
# 719

# %%
# Ataques en España?
df_spain = df[df["country"] == "SPAIN"]
len(df_spain)
# Out:
# (5, 13)

# %%
# 3.1 ¿En qué regiones se han producido los ataques?
df_spain.head()
# Out:
#        case_number    year        type country                 area  \
# 98    2017.08.26.b  2017.0     Invalid   SPAIN            Castellón
# 233     2016.07.29  2016.0  Unprovoked   SPAIN    Alicante Province
# 377   2015.08.18.a  2015.0     Invalid   SPAIN             Alicante
# 1007  2010.07.16.b  2010.0    Provoked   SPAIN  Grand Canary Island
# 2469    1993.09.03  1993.0  Unprovoked   SPAIN         Costa Blanca
#
#                             location  activity  \
# 98                   Grao de Moncofa  Swimming
# 233                 Arenales del Sol  Swimming
# 377         Poniente Beach, Benidorm  Swimming
# 1007       Sardina del Norte, Gáldar  Swimming
# 2469  Playa de las Arenas, Valencia   Swimming
#
#                                      name sex_ age    time  \
# 98                                 female    F  11  Midday
# 233                                  male    M  40   11h30
# 377                                  male    M  10   11h00
# 1007                                 male    M   9   19h15
# 2469  Jorge Durich Heredia (or Hernandez)    M  69   08h00
#
#                              species_  \
# 98     Shark involvement questionable
# 233                        Blue shark
# 377   Shark involvement not confirmed
# 1007                      Angel shark
# 2469                 1.2 m [4'] shark
#
#                                                    href
# 98    http://sharkattackfile.net/spreadsheets/pdf_di...
# 233   http://sharkattackfile.net/spreadsheets/pdf_di...
# 377   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1007  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2469  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
######################################################
#estas son las regiones donde se han producido los ataques
df_spain["area"].unique
# Out:
# <bound method Series.unique of 82           Canary Islands
# 98                Castellón
# 113                 Majorca
# 130            Ibiza Island
# 233       Alicante Province
# 248          Canary Islands
# 320     Grand Canary Island
# 377                Alicante
# 470                 Granada
# 503               Catalonia
# 508                Alicante
# 527          Canary Islands
# 654               Catalonia
# 1007    Grand Canary Island
# 1102              Catalunya
# 1452               Alicante
# 2469           Costa Blanca
# 2813              Catalonia
# 2814                  Cádiz
# 3050         Canary Islands
# 3399         Canary Islands
# 3847              Catalonia
# 5026         Canary Islands
# 5053               Valencia
# 5137          Sants-Montjic
# 5151              Valencia
# 5175                 Galica
# 5294           Gran Canaria
# 5363              Balearics
# 5370                Málaga
# 5405              Andalucia
# 5416                Galicia
# 5417         Canary Islands
# 5814               Valencia
# 5926       Eastern Catalona
# 5949                    NaN
# 5950                 Malaga
# 5951                 Malaga
# 5952                  Cádiz
# 5953                  Cádiz
# 6062                    NaN
# 6092                    NaN
# Name: area, dtype: object>

# %%
# 3.2 ¿Cuántos ataques se han producido en cada área?
df_spain["area"].count
# Out:
# <bound method Series.count of 82           Canary Islands
# 98                Castellón
# 113                 Majorca
# 130            Ibiza Island
# 233       Alicante Province
# 248          Canary Islands
# 320     Grand Canary Island
# 377                Alicante
# 470                 Granada
# 503               Catalonia
# 508                Alicante
# 527          Canary Islands
# 654               Catalonia
# 1007    Grand Canary Island
# 1102              Catalunya
# 1452               Alicante
# 2469           Costa Blanca
# 2813              Catalonia
# 2814                  Cádiz
# 3050         Canary Islands
# 3399         Canary Islands
# 3847              Catalonia
# 5026         Canary Islands
# 5053               Valencia
# 5137          Sants-Montjic
# 5151              Valencia
# 5175                 Galica
# 5294           Gran Canaria
# 5363              Balearics
# 5370                Málaga
# 5405              Andalucia
# 5416                Galicia
# 5417         Canary Islands
# 5814               Valencia
# 5926       Eastern Catalona
# 5949                    NaN
# 5950                 Malaga
# 5951                 Malaga
# 5952                  Cádiz
# 5953                  Cádiz
# 6062                    NaN
# 6092                    NaN
# Name: area, dtype: object>

# %%
################################este no da nadaaaa.. estará bien??? 
# Extrae un dataframe nuevo con los ataques que se han producido en Australia y Estados Unidos. 
# 📌 Nota Este ejercicio se puede resolver usando dos condiciones de filtrado o usando el método isin(). Hacedlo con ambas herramientas.
df_countries = df[(df["country"] == "USA") & (df["country"] == "AUSTRALIA")]
df_countries.head()
# Out:
# Empty DataFrame
# Columns: [case_number, year, type, country, area, location, activity, name, sex_, age, time, species_, href]
# Index: []

# %%
######## error porque USa y AUS es string
#método isin
df_countries2 = [df["country"].isin("USA"),df["country"].isin("AUSTRALIA")]
df_countries2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2048/776959710.py in <module>
#       1 ######## error porque USa y AUS es string
#       2 #método isin
# ----> 3 df_countries2 = [df["country"].isin("USA"),df["country"].isin("AUSTRALIA")]
#       4 df_countries2
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in isin(self, values)
#    5023         dtype: bool
#    5024         """
# -> 5025         result = algorithms.isin(self._values, values)
#    5026         return self._constructor(result, index=self.index).__finalize__(
#    5027             self, method="isin"
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/algorithms.py in isin(comps, values)
#     457         )
#     458     if not is_list_like(values):
# --> 459         raise TypeError(
#     460             "only list-like objects are allowed to be passed "
#     461             f"to isin(), you passed a [{type(values).__name__}]"
#
# TypeError: only list-like objects are allowed to be passed to isin(), you passed a [str]

# %%
# 4.1 ¿Cuántos ataques se han producido en cada pais?
df["year"].unique
# Out:
# <bound method Series.unique of 0       2018.0
# 6       2018.0
# 8       2018.0
# 10      2018.0
# 13      2018.0
#          ...
# 5528    1901.0
# 5631    1894.0
# 5667    1892.0
# 5797    1880.0
# 5905    1868.0
# Name: year, Length: 1502, dtype: float64>

# %%
# 4.2 ¿Ha habido ataques en Australia a gente que estuviera remando (lo encontrareis como Paddling en el dataframe en la columna activity)?

df_aus_padd = df[(df["country"] == "AUSTRALIA") & (df["activity"] == "Paddling")]
df_aus_padd
# Out:
# Empty DataFrame
# Columns: [case_number, year, type, country, area, location, activity, name, sex_, age, time, species_, href]
# Index: []

# %%
# 4.3 ¿Cuántos ataques se han producido en Australia antes del 2000?
df_aus_antiguos = df[(df["country"] == "AUSTRALIA") & (df["year"] < 2000.0)]
len(df_aus_antiguos)
# Out:
# 151

# %%
# 4.4 ¿Y después del 2000?
df_aus_recientes = df[(df["country"] == "AUSTRALIA") & (df["year"] > 2000.0)]
len(df_aus_recientes)
# Out:
# 167

# %%
df_fem = df["sex_"]
df_fem
# Out:
# 0       F
# 6       M
# 8       M
# 10      M
# 13      M
#        ..
# 5528    M
# 5631    M
# 5667    M
# 5797    M
# 5905    M
# Name: sex_, Length: 1502, dtype: object

# %%
# Extraed unicamente los ataques a mujeres
df_fem = df[(df["sex_"] == "F")]
df_fem
# Out:
#        case_number    year        type           country               area  \
# 0       2018.06.25  2018.0     Boating               USA         California
# 1       2018.06.18  2018.0  Unprovoked               USA            Georgia
# 14      2018.05.00  2018.0    Provoked         AUSTRALIA  Westerm Australia
# 40      2018.02.23  2018.0  Unprovoked         AUSTRALIA    New South Wales
# 43      2018.02.14  2018.0     Invalid         AUSTRALIA         Queensland
# ...            ...     ...         ...               ...                ...
# 5985  1855.04.09.R  1855.0  Unprovoked         AUSTRALIA    South Australia
# 6002    1852.07.28  1852.0     Invalid    ATLANTIC OCEAN                NaN
# 6017  1849.06.08.a  1849.0  Unprovoked               USA            Florida
# 6066  1834.07.15.R  1834.0  Unprovoked  FRENCH POLYNESIA    Society Islands
# 6067    1832.06.04  1832.0  Unprovoked         AUSTRALIA    New South Wales
#
#                                 location                         activity  \
# 0            Oceanside, San Diego County                         Paddling
# 1         St. Simon Island, Glynn County                         Standing
# 14                            Dugong Bay                   Feeding sharks
# 40    Little Congwong Beach, La Perouse                          Swimming
# 43                      Mooloolaba Beach                         Swimming
# ...                                  ...                              ...
# 5985                      Port Wakefield  Fell overboard from the Malacca
# 6002                                 NaN                              NaN
# 6017          Pensacola, Escambia County                          Bathing
# 6066                              Tahiti                         Swimming
# 6067                  South Head, Sydney                          Fishing
#
#                         name sex_  age           time  \
# 0                Julie Wolfe    F   57          18h00
# 1            Adyson McNeely     F   11  14h00  -15h00
# 14           Melisa Brunning    F   34            NaN
# 40            Anna Shurapey     F   55    19h00, Dusk
# 43               Sharna Babd    F  NaN          18h00
# ...                      ...  ...  ...            ...
# 5985                   child    F   2½            NaN
# 6002  Karen Bredesen Stræte     F    1            NaN
# 6017            Mrs. Cracton    F  NaN            NaN
# 6066       Kaugatava Orurutm    F  NaN            NaN
# 6067       Aboriginal female    F  NaN            NaN
#
#                                     species_  \
# 0                                White shark
# 1                                        NaN
# 14                     Tawny nurse shark, 2m
# 40       Juvenile white shark,  2.7 to 3.2 m
# 43                      Possibly a wobbegong
# ...                                      ...
# 5985                                     NaN
# 6002                                 Invalid
# 6017                                     NaN
# 6066  Reported to involve a hammerhead shark
# 6067                                     NaN
#
#                                                    href
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 14    http://sharkattackfile.net/spreadsheets/pdf_di...
# 40    http://sharkattackfile.net/spreadsheets/pdf_di...
# 43    http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 5985  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6002  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6017  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6066  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6067  http://sharkattackfile.net/spreadsheets/pdf_di...
#
# [619 rows x 13 columns]

# %%
# ¿Cuántas mujeres fueron atacadas en España?
df_sex_country = df[["sex_","country"]]
print(df_sex_country)
# Out:
#      sex_    country
# 0       F        USA
# 1       F        USA
# 2       M        USA
# 3       M  AUSTRALIA
# 4       M     MEXICO
# ...   ...        ...
# 6109  NaN  AUSTRALIA
# 6110    M        USA
# 6111    M  AUSTRALIA
# 6112  NaN      INDIA
# 6113    N        NaN
#
# [6114 rows x 2 columns]

# %%
# ¿Cuántas mujeres fueron atacadas en España?
df_fem_spain = df[(df["sex_"] == "F") & (df["country"] == "SPAIN")]
len(df_fem_spain)
# Out:
# 9

# %%
# 7. Extraed los ataques que se hayan producido en el año 2000, 1997 y 2006. Utilizad el método isin() para resolver este ejercicio.
df_ataques_2000 = df[df["year"].isin([2000.0])]
df_ataques_2000.head(2)
# Out:
#      case_number    year        type    country        area  \
# 1975  2000.12.24  2000.0  Unprovoked  AUSTRALIA  Queensland
# 1976  2000.12.12  2000.0  Unprovoked       FIJI     Taveuni
#
#                   location                              activity  \
# 1975          Flinders Cay                          Scuba diving
# 1976  Garden Island Resort  Swimming back from anchored sailboat
#
#                 name sex_ age   time         species_  \
# 1975            male    M  23    NaN              NaN
# 1976  Michael Loxton    M  47  14h30  6 m [20'] shark
#
#                                                    href
# 1975  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1976  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
# ataques 1997
df_ataques_1997 = df[df["year"].isin([1997.0])]
df_ataques_1997.head(2)
# Out:
#        case_number    year        type       country                   area  \
# 2203  1997.12.28.b  1997.0  Unprovoked  SOUTH AFRICA  Western Cape Province
# 2204  1997.12.28.a  1997.0  Unprovoked  SOUTH AFRICA  Eastern Cape Province
#
#                                           location              activity  \
# 2203  Pringle Bay, 44 miles southeast of Cape Town          Spearfishing
# 2204                               St. Francis Bay  Sitting on surfboard
#
#                  name sex_  age   time     species_  \
# 2203   Ian James Hill    M   39  14h00  White shark
# 2204  Stuart Buchanan    M  NaN    NaN          NaN
#
#                                                    href
# 2203  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2204  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
# ataques 2006
df_ataques_2006 = df[df["year"].isin([2006.0])]
df_ataques_2006.head(2)
# Out:
#      case_number    year        type      country          area  \
# 1407  2006.12.18  2006.0  Unprovoked    AUSTRALIA      Victoria
# 1408  2006.12.11  2006.0  Unprovoked  NEW ZEALAND  North Island
#
#                     location activity                  name sex_ age   time  \
# 1407  Winki Pop, Bells Beach  Surfing          Peter Galvin    M  25  20h00
# 1408        Raglan, Manu Bay  Surfing  Elliot Paerata-Reid     M  10  11h00
#
#               species_                                               href
# 1407  2.5 to 3 m shark  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1408    2 to 3 m shark  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
# 8. Si extraemos los valores únicos de la columna species nos podemos dar cuenta que esta un poco sucia y extraer informacion útil de la misma.
# En este ejercicio tendréis que extraer los ataques que han ocurrido por tiburón blanco (lo encontraremos en la columna species como algo que contenga white o White). 
# Usad el método str.contains() para resolver este ejercicio.

df_ataque_tiburon = df[df['species_'].str.contains('white', 'White', na= False, regex = True)]
df_ataque_tiburon.head(2)
# Out:
#     case_number    year        type    country                  area  \
# 40   2018.02.23  2018.0  Unprovoked  AUSTRALIA       New South Wales
# 103  2017.08.05  2017.0  Unprovoked      EGYPT  Red Sea Protectorate
#
#                                location    activity                 name sex_  \
# 40   Little Congwong Beach, La Perouse     Swimming       Anna Shurapey     F
# 103                        Marsa Ghalib  Snorkeling  Kirsten Schachinger    F
#
#     age         time                             species_  \
# 40   55  19h00, Dusk  Juvenile white shark,  2.7 to 3.2 m
# 103  20          NaN   Oceanic whitetip shark, 1.8 to 2 m
#
#                                                   href
# 40   http://sharkattackfile.net/spreadsheets/pdf_di...
# 103  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
# 9. Extraed ahora los ataques por tiburón blanco o tigre. Utilizad el método str.contains() para resolver este ejercicio.
df_tiburon_tigre = df[df['species_'].str.contains('White','Tiger', na= False, regex = True)]
df_tiburon_tigre.sample()
# Out:
#      case_number    year        type country      area  \
# 3028  1981.03.04  1981.0  Unprovoked   CHILE  Coquimbo
#
#                                          location                  activity  \
# 3028  Bahia Totoralillo, 80  km north of Coquimbo  Free diving Spearfishing
#
#                   name sex_  age   time     species_  \
# 3028  Carlos Veraga M.    M  NaN  10h30  White shark
#
#                                                    href
# 3028  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
# 10 . Utilizando la columna de year cread una nueva columna llamada siglo que siglo-XX o siglo-XXI. 
# Donde el año sea menor que 2000 pondremos siglo-XX y el resto de los años siglo-XXI.

df_siglo = pd.DataFrame({'siglo_xx': ['year' < 2000], 'siglo_xxi': ['year' > 2000]})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/cc/w29nscnn2p75y27g1lx9hz000000gn/T/ipykernel_37718/1313379087.py in <module>
#       2 # Donde el año sea menor que 2000 pondremos siglo-XX y el resto de los años siglo-XXI.
#       3
# ----> 4 df_siglo = pd.DataFrame({'siglo_xx': [int('year') < 2000], 'siglo_xxi': [int('year') > 2000]})
#
# ValueError: invalid literal for int() with base 10: 'year'
