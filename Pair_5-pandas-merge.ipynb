# %%
import pandas as pd
#haz histodiseal.columns desde pandas 3

# %%
# Carga los tres ficheros nombrados anteriormente y los exploramos para familizarizarnos con ellos 
# y saber que información tienen en común y debatir con tu compañera como podríamos juntar toda la información.
historico = pd.read_csv("attacks_historico.csv")
historico.head(2)
# Out:
#    Unnamed: 0   Case Number    Year        Type     Country      Area  \
# 0        6132    1800.00.00  1800.0  Unprovoked  SEYCHELLES  St. Anne
# 1        6133  1797.05.28.R  1797.0  Unprovoked         NaN       NaN
#
#   Location                         Activity   Name Sex   ... Species   \
# 0      NaN  a corsair's boat was overturned    NaN    F  ...      NaN
# 1      NaN                Dropped overboard  child  NaN  ...      NaN
#
#    Investigator or Source                          pdf  \
# 0      V. C. Harvey-Brain  1800.00.00-Corsair-boat.pdf
# 1  The Observer 5/28/1797  1797.05.28.R-Cloverdale.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    1800.00.00
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...  1797.05.28.R
#
# ...

# %%
adicional = pd.read_csv("attacks_adicional.csv", index_col = 0)                     #desaparece la columna unnamed_0.
adicional.head(2)
# Out:
#   Case Number Fatal (Y/N)                                             Injury  \
# 0  2018.06.25           N  No injury to occupant, outrigger canoe and pad...
# 1  2018.06.18           N                         Minor injury to left thigh
#
#           Date
# 0  25-Jun-2018
# 1  18-Jun-2018

# %%
odisea = pd.read_csv("odisea.csv")
odisea.head(2)
# Out:
#   case_number  unnamed:_0    year        type country        area  \
# 0  2018.06.25           0  2018.0     Boating     USA  California
# 1  2018.06.18           1  2018.0  Unprovoked     USA     Georgia
#
#                          location  activity             name sex_ age  \
# 0     Oceanside, San Diego County  Paddling      Julie Wolfe    F  57
# 1  St. Simon Island, Glynn County  Standing  Adyson McNeely     F  11
#
#             time     species_  \
# 0          18h00  White shark
# 1  14h00  -15h00          NaN
#
#                                                 href
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
#cambiamos nombres de la columna. Vamos a unir por la columna case_number. Odisea es el csv de pandas 3 en el que vamos a unir los otros dos dfs

#cambiamos el nombre en historico
nuevas_columnas = {}

for col in historico.columns:
    nuevas_columnas[col] = col.lower()
    historico.rename(columns = nuevas_columnas, inplace = True)
    nuevas_columnas[col] = col.replace(" ", "_")
print(historico)

# %%
#cambiamos el nombre en adicional
for col in adicional.columns:
    nuevas_columnas[col] = col.lower()
    adicional.rename(columns = nuevas_columnas, inplace = True)
    nuevas_columnas[col] = col.replace(" ", "_")
print(adicional)

# %%
# modificar dfs para que sean iguales.


#observamos cómo son nuestos dfs
odisea.shape
historico.head(2)
# Out:
#    unnamed:_0   case_number    year        type     country      area  \
# 0        6132    1800.00.00  1800.0  Unprovoked  SEYCHELLES  St. Anne
# 1        6133  1797.05.28.R  1797.0  Unprovoked         NaN       NaN
#
#   location                         activity   name sex_  ... species_  \
# 0      NaN  a corsair's boat was overturned    NaN    F  ...      NaN
# 1      NaN                Dropped overboard  child  NaN  ...      NaN
#
#    investigator_or_source                          pdf  \
# 0      V. C. Harvey-Brain  1800.00.00-Corsair-boat.pdf
# 1  The Observer 5/28/1797  1797.05.28.R-Cloverdale.pdf
#
#                                         href_formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href case_number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    1800.00.00
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...  1797.05.28.R
#
# ...

# %%
#eliminamos las cols que no nos interesan
historico.drop(["unnamed:_22", "unnamed:_23", "case_number.1", "case_number.2", "original_order", 
"investigator_or_source", "pdf", "href_formula"], axis = 1, inplace= True)

# %%
historico.columns
# Out:
# Index(['unnamed:_0', 'case_number', 'year', 'type', 'country', 'area',
#        'location', 'activity', 'name', 'sex_', 'age', 'time', 'species_',
#        'href'],
#       dtype='object')

# %%
odisea.columns
# Out:
# Index(['case_number', 'unnamed:_0', 'year', 'type', 'country', 'area',
#        'location', 'activity', 'name', 'sex_', 'age', 'time', 'species_',
#        'href'],
#       dtype='object')

# %%
# cambiamos el orden de las columnas de historico al mismo que de odisea (el csv de pandas 3)
historico.reindex(columns= odisea.columns)
# Out:
#       case_number  unnamed:_0    year        type             country  \
# 0      1800.00.00        6132  1800.0  Unprovoked          SEYCHELLES
# 1    1797.05.28.R        6133  1797.0  Unprovoked                 NaN
# 2      1792.09.12        6134  1792.0    Provoked             ENGLAND
# 3      1791.00.00        6135  1791.0  Unprovoked           AUSTRALIA
# 4      1788.05.10        6136  1788.0        Boat           AUSTRALIA
# ..            ...         ...     ...         ...                 ...
# 165       ND.0005        6297     0.0  Unprovoked           AUSTRALIA
# 166       ND.0004        6298     0.0  Unprovoked           AUSTRALIA
# 167       ND.0003        6299     0.0  Unprovoked                 USA
# 168       ND.0002        6300     0.0  Unprovoked              PANAMA
# 169       ND.0001        6301     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                   area                             location  \
# 0             St. Anne                                  NaN
# ...

# %%
# unir dfs ya iguales (historico y odisea)

histodisea = pd.concat([historico, odisea], axis = 0, join = 'outer', ignore_index = False,)

# %%
odisea.shape
# Out:
# (6114, 14)

# %%
historico.shape
# Out:
# (170, 14)

# %%
histodisea.shape
# Out:
# (6284, 14)

# %%
#requetecomprobando que está todas las filas sumando
# 170 + 6114

# %%
histodisea.head(2)
# Out:
#    unnamed:_0   case_number    year        type     country      area  \
# 0        6132    1800.00.00  1800.0  Unprovoked  SEYCHELLES  St. Anne
# 1        6133  1797.05.28.R  1797.0  Unprovoked         NaN       NaN
#
#   location                         activity   name sex_  age time species_  \
# 0      NaN  a corsair's boat was overturned    NaN    F  NaN  NaN      NaN
# 1      NaN                Dropped overboard  child  NaN  NaN  NaN      NaN
#
#                                                 href
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
adicional.head(2)
# Out:
#   Case Number Fatal (Y/N)                                             Injury  \
# 0  2018.06.25           N  No injury to occupant, outrigger canoe and pad...
# 1  2018.06.18           N                         Minor injury to left thigh
#
#           Date
# 0  25-Jun-2018
# 1  18-Jun-2018

# %%
# Ejercicio 4. Unir histodisea + adicional

histodiseal = histodisea.merge(adicional, how = "left", on = "case_number")

# %%
histodiseal.columns
# Out:
# Index(['unnamed:_0_x', 'case_number', 'year', 'type', 'country', 'area',
#        'location', 'activity', 'name', 'sex_', 'age', 'time', 'species_',
#        'href', 'unnamed:_0_y', 'fatal_(y/n)', 'injury', 'date'],
#       dtype='object')

# %%
#mira si  date tiene los mismos valores en ambas dfs para poder eliminarlas.

# %%
histodiseal["date"]
# Out:
# 0                       1800
# 1       Reported May-28-1797
# 2                12-Sep-1792
# 3                       1791
# 4                10-May-1788
#                 ...
# 6279    Reported 26-Feb-1804
# 6280             May-17-1803
# 6281                Mar-1803
# 6282    Reported Apr-13-1802
# 6283    Reported 18-Dec-1801
# Name: date, Length: 6284, dtype: object

# %%
odisea["date"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
